# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
def get_jobs_list(soup_GD):
    try:
        jobs_list = soup_GD.find_all('li', class_='JobsList_jobListItem__JBBUV')
    except AttributeError:
        jobs_list = []
        
    return jobs_list

# %%
def get_comp_name(soup_GD, job):
    try:
        company_name = job.find('div', class_='css-8wag7x').text
        company_name = ''.join(i for i in company_name if ((i.isalpha()) | (i == ' ')))
        company_name = company_name.strip()
    except AttributeError:
        company_name = ''
        
    return company_name

# %%
def get_job_location(soup_GD, job):
    try:
        job_location = job.find('div', class_='location mt-xxsm').text
    except AttributeError:
        job_location = ''
        
    return job_location

# %%
def get_job_salary(soup_GD, job):
    try:
        estimated_salary = job.find('div', class_='salary-estimate').text.split('\xa0')[0]
    except AttributeError:
        estimated_salary = ''
        
    return estimated_salary

# %%
URL_GD = 'https://www.glassdoor.co.in/Job/india-data-engineer-jobs-SRCH_IL.0,5_IN115_KO6,19.htm'
Hearders = ({'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36', 'Accept-Language': 'en-US,en;q=0.5'})

webpage = requests.get(URL_GD, headers=Hearders)
company_name = []
job_location = []
estimated_salary = []
soup_GD = BeautifulSoup(webpage.content, 'html.parser')
jobs_list = get_jobs_list(soup_GD)

for job in jobs_list:
    company_name.append(get_comp_name(soup_GD, job))
    job_location.append(get_job_location(soup_GD, job))
    estimated_salary.append(get_job_salary(soup_GD, job))
    
print(company_name)
print(len(company_name))
print(job_location)
print(estimated_salary)
info_dic = {'company_name': company_name, 'job_location': job_location, 'estimated_salary': estimated_salary}
print(info_dic)
# Out:
# ['Stefanini Inc', 'Indeed', '', 'HP', '', 'ICF', 'Grid Infocom', 'Codvoai', 'Maersk', 'True Tech Professionals Private Limited', 'Forbes Advisor', 'World Wide Technology Holding LLC', 'ZF', 'RamSoft', 'Irdeto', 'Ameriprise India', '', '', '', '']
# 20
# ['Gurgaon', 'Hyderābād', 'India', 'Bengaluru', 'Remote', 'New Delhi', 'Remote', 'Remote', 'Bengaluru', 'Gurgaon', 'Mumbai', 'Gurgaon', 'Hyderābād', 'Bengaluru', 'New Delhi', 'Noida', 'Hyderābād', 'Gurgaon', 'Farīdābād', 'Bengaluru']
# ['₹4L - ₹7L', '₹54L - ₹80L', '₹5L - ₹6L', '₹8L - ₹9L', '', '₹4L - ₹8L', '₹3L', '₹5L - ₹18L', '₹4L - ₹9L', '₹10L - ₹40L', '₹2L - ₹7L', '₹4L - ₹6L', '₹7L - ₹8L', '₹7L - ₹10L', '₹6L - ₹7L', '', '₹10L - ₹15L', '₹4L - ₹6L', '₹4L - ₹10L', '₹28L']
# {'company_name': ['Stefanini Inc', 'Indeed', '', 'HP', '', 'ICF', 'Grid Infocom', 'Codvoai', 'Maersk', 'True Tech Professionals Private Limited', 'Forbes Advisor', 'World Wide Technology Holding LLC', 'ZF', 'RamSoft', 'Irdeto', 'Ameriprise India', '', '', '', ''], 'job_location': ['Gurgaon', 'Hyderābād', 'India', 'Bengaluru', 'Remote', 'New Delhi', 'Remote', 'Remote', 'Bengaluru', 'Gurgaon', 'Mumbai', 'Gurgaon', 'Hyderābād', 'Bengaluru', 'New Delhi', 'Noida', 'Hyderābād', 'Gurgaon', 'Farīdābād', 'Bengaluru'], 'estimated_salary': ['₹4L - ₹7L', '₹54L - ₹80L', '₹5L - ₹6L', '₹8L - ₹9L', '', '₹4L - ₹8L', '₹3L', '₹5L - ₹18L', '₹4L - ₹9L', '₹10L - ₹40L', '₹2L - ₹7L', '₹4L - ₹6L', '₹7L - ₹8L', '₹7L - ₹10L', '₹6L - ₹7L', '', '₹10L - ₹15L', '₹4L - ₹6L', '₹4L - ₹10L', '₹28L']}

# %%
df = pd.DataFrame.from_dict(info_dic)

# %%
df
# Out:
#                                company_name job_location estimated_salary
# 0                             Stefanini Inc      Gurgaon        ₹4L - ₹7L
# 1                                    Indeed    Hyderābād      ₹54L - ₹80L
# 2                                                  India        ₹5L - ₹6L
# 3                                        HP    Bengaluru        ₹8L - ₹9L
# 4                                                 Remote
# 5                                       ICF    New Delhi        ₹4L - ₹8L
# 6                              Grid Infocom       Remote              ₹3L
# 7                                   Codvoai       Remote       ₹5L - ₹18L
# 8                                    Maersk    Bengaluru        ₹4L - ₹9L
# 9   True Tech Professionals Private Limited      Gurgaon      ₹10L - ₹40L
# 10                           Forbes Advisor       Mumbai        ₹2L - ₹7L
# 11        World Wide Technology Holding LLC      Gurgaon        ₹4L - ₹6L
# 12                                       ZF    Hyderābād        ₹7L - ₹8L
# 13                                  RamSoft    Bengaluru       ₹7L - ₹10L
# 14                                   Irdeto    New Delhi        ₹6L - ₹7L
# 15                         Ameriprise India        Noida
# 16                                             Hyderābād      ₹10L - ₹15L
# 17                                               Gurgaon        ₹4L - ₹6L
# 18                                             Farīdābād       ₹4L - ₹10L
# 19                                             Bengaluru             ₹28L
